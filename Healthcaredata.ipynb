# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd

df = pd.read_csv("healthcare_dataset.csv")
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# ...

# %%
df.tail()
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# 9995        2022-07-29       Samuel Moody   Wood, Martin and Simmons
# 9996        2022-01-06  Christopher Yates               Nash-Krueger
# 9997        2022-07-01   Robert Nicholson            Larson and Sons
# 9998        2020-02-06        Jamie Lewis               Wilson-Lyons
# 9999        2023-03-22        Tasha Avila  Torres, Young and Stewart
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.to_csv('HealthcareDataset.csv', index= False)

# %%
df['Medical Condition'].value_counts()
# Out:
# Medical Condition
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: count, dtype: int64

# %%
df['Admission Type'].value_counts()
# Out:
# Admission Type
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: count, dtype: int64

# %%
df['Medication'].value_counts()
# Out:
# Medication
# Penicillin     2079
# Lipitor        2015
# Ibuprofen      1976
# Aspirin        1968
# Paracetamol    1962
# Name: count, dtype: int64

# %%
df['Test Results'].value_counts()
# Out:
# Test Results
# Abnormal        3456
# Inconclusive    3277
# Normal          3267
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.agg(['min','max'])
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# min  Aaron Burnett   18  Female         A+         Arthritis
# max      Zoe Moore   85    Male         O-           Obesity
#
#     Date of Admission          Doctor        Hospital Insurance Provider  \
# min        2018-10-30  Aaron Anderson      Abbott Inc              Aetna
# max        2023-10-30     Zoe Jenkins  Zuniga-Johnson   UnitedHealthcare
#
#      Billing Amount  Room Number Admission Type Discharge Date  Medication  \
# min     1000.180837          101       Elective     2018-11-01     Aspirin
# max    49995.902283          500         Urgent     2023-11-27  Penicillin
#
#     Test Results
# min     Abnormal
# max       Normal

# %%
df.sort_values(by='Billing Amount')
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 36         Anna Adams   70  Female         A+           Obesity
# 2239    Shane Griffin   31    Male        AB-           Obesity
# 3147     Ashley Novak   62  Female        AB-         Arthritis
# 4866      Tonya Smith   51  Female         A+            Cancer
# 766          John Kim   74    Male        AB+            Asthma
# ...               ...  ...     ...        ...               ...
# 3526    Richard Jones   59  Female         A+            Asthma
# 734        Mary Stein   35    Male         A+      Hypertension
# 3256         Roy Beck   79  Female         A-         Arthritis
# 9384  Teresa Buchanan   75    Male         B+            Cancer
# 8789      Daniel Hall   77    Male         A+      Hypertension
#
#      Date of Admission               Doctor                    Hospital  \
# 36          2022-09-06        Samuel Taylor                  Snow Group
# ...

# %%
df.groupby(by = 'Blood Type').count()
# Out:
#             Name   Age  Gender  Medical Condition  Date of Admission  Doctor  \
# Blood Type
# A+          1241  1241    1241               1241               1241    1241
# A-          1238  1238    1238               1238               1238    1238
# AB+         1258  1258    1258               1258               1258    1258
# AB-         1275  1275    1275               1275               1275    1275
# B+          1244  1244    1244               1244               1244    1244
# B-          1252  1252    1252               1252               1252    1252
# O+          1248  1248    1248               1248               1248    1248
# O-          1244  1244    1244               1244               1244    1244
#
#             Hospital  Insurance Provider  Billing Amount  Room Number  \
# Blood Type
# A+              1241                1241            1241         1241
# A-              1238                1238            1238         1238
# ...

# %%
df['Medical Condition'].value_counts().plot(kind='bar', title='Count plot for Medical Condition', xlabel='Medical COndition', ylabel='count')
# Out:
# <Axes: title={'center': 'Count plot for Medical Condition'}, xlabel='Medical COndition', ylabel='count'>

# %%
import matplotlib.pyplot as plt
x = df['Test Results'].value_counts()
plt.pie(x, labels=x.index, autopct='%d%%')
plt.show()

# %%
import matplotlib.pyplot as plt
x = df['Medication'].value_counts()
plt.pie(x, labels=x.index, autopct='%d%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x='Test Results', data=df, palette="Set1")
# Out:
# <Axes: xlabel='Test Results', ylabel='count'>

# %%
sns.histplot(data=df, x=df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
import seaborn as sns
sns.pairplot(df)

# %%
import seaborn as sns
sns.pairplot(df, hue='Age')
